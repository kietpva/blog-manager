# %% [markdown]
# # **Functions**
# ## **Avoid using a mutable object as the `default value` for a function argument**
# **❌ DON'T**

# %%
def add_item(item, items=[]):
    items.append(item)
    return items

print(add_item("apple"))
print(add_item("banana"))
print(add_item("orange"))
# Out:
# ['apple']
# ['apple', 'banana']
# ['apple', 'banana', 'orange']

# %% [markdown]
# **✔️ DO**

# %%
def add_item(item, items=None):
    if items is None:
        items = []

    items.append(item)
    return items

print(add_item("apple"))
print(add_item("banana"))
print(add_item("orange"))
# Out:
# ['apple']
# ['banana']
# ['orange']

# %% [markdown]
# ## **Use `return` to evaluate expressions in addition to return values**
# **❌ DON'T**

# %%
def is_even(n):
    if n % 2 == 0:
        result = True
    else:
        result = False
    return result

print(is_even(4))
print(is_even(7))
# Out:
# True
# False

# %% [markdown]
# **✔️ DO**

# %%
def is_even(n):
    return n % 2 == 0

print(is_even(4))
print(is_even(7))
# Out:
# True
# False

# %% [markdown]
# ## **Learn to use `keyword arguments` properly**

# %% [markdown]
# **❌ DON'T**

# %%
def print_list(list_value, sep):
    print('{}'.format(sep).join(list_value))
the_list = ['a', 'b', 'c']
the_other_list = ['Jeff', 'hates', 'Java']
print_list(the_list, ' ')
print_list(the_other_list, ' ')
print_list(the_other_list, ', ')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       3 the_list = ['a', 'b', 'c']
#       4 the_other_list = ['Jeff', 'hates', 'Java']
# ----> 5 print_list(the_list)
#       6 print_list(the_other_list, ' ')
#       7 print_list(the_other_list, ', ')
#
# TypeError: print_list() missing 1 required positional argument: 'sep'

# %% [markdown]
# **✔️ DO**

# %%
def print_list(list_value, sep=' '):
    print('{}'.format(sep).join(list_value))
the_list = ['a', 'b', 'c']
the_other_list = ['Jeff', 'hates', 'Java']
print_list(the_list)
print_list(the_other_list)
print_list(the_other_list, ', ')
# Out:
# a b c
# Jeff hates Java
# Jeff, hates, Java
