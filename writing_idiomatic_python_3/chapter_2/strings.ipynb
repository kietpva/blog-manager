# %% [markdown]
# # **Strings**
# ## **Chain string functions to make a simple series of transformations more clear**
# *No more than three chained functions*
#
# **❌ DON'T**

# %%
book_info = ' The Three Musketeers: Alexandre Dumas'
formatted_book_info = book_info.strip()
formatted_book_info = formatted_book_info.upper()
formatted_book_info = formatted_book_info.replace(':', ' by')

print(formatted_book_info)
# Out:
# THE THREE MUSKETEERS by ALEXANDRE DUMAS

# %% [markdown]
# **✔️ DO**

# %%
book_info = " The Three Musketeers: Alexandre Dumas"
formatted_book_info = book_info.strip().upper().replace(":", " by")

print(formatted_book_info)
# Out:
# THE THREE MUSKETEERS BY ALEXANDRE DUMAS

# %% [markdown]
# ## **Use `''.join` when creating a single `string` for `list` elements**
# **❌ DON'T**

# %%
result_list = ['True', 'False', 'File not found']
result_string = ''
for result in result_list:
    result_string += result

print(result_string)
# Out:
# TrueFalseFile not found

# %% [markdown]
# **✔️ DO**

# %%
result_list = ["True", "False", "File not found"]
result_string = "".join(result_list)

print(result_string)
# Out:
# TrueFalseFile not found

# %% [markdown]
# ## **Use `ord` to get the ASCII code of a character and `chr` to get the character from an ASCIIcode**
# - `ord()`
#   - takes a single character
#   - Returns its ASCII / Unicode code point
# - `chr()`
#   - takes an integer
#   - Returns the corresponding character

# %%
print(ord("A"))
print(ord("a"))
print(ord("0"))

print(chr(65))
print(chr(97))
print(chr(48))
# Out:
# 65
# 97
# 48
# A
# a
# 0
