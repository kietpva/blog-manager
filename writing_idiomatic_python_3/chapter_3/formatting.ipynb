# %% [markdown]
# # **Formatting**
# ## **Use all capital letters when declaring global constant values**
# **❌ DON'T**

# %%
taxRate = 0.1
MaxRetries = 5
default_timeout = 30

# %% [markdown]
# **✔️ DO**

# %%
TAX_RATE = 0.1
MAX_RETRIES = 5
DEFAULT_TIMEOUT = 30
API_BASE_URL = "https://api.example.com"
